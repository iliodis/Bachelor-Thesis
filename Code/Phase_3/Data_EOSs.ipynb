# %%
from pathlib import Path
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib as mpl

# %%
path0 = Path(r"C:\Users\You\Desktop\Σχολή\MR_EGB\apr3\MR_data")

# %%
file_list = glob.glob(str(path0.joinpath("*")))

# %%
# Units
units = {
    'M'  :'M_{\odot}',
    'R'  :'km',
    'p_c':'10^{25} dyn/cm^2'
}

# %%
df = pd.DataFrame({})
alpha_list = []
for file_name in file_list:
    
    alpha = file_name[53:]
    temp  = pd.read_table(file_name, sep="\s+", names= ['M','R','p_c'])
    
    temp['a'] = np.ones(len(temp))*float(alpha)
    
    alpha_list.append(float(alpha))
    
    frames = [df,temp]
    df     = pd.concat(frames, ignore_index=True)

# %%
# df_alpha = pd.DataFrame({'a':alpha_list})
# df_alpha.to_csv(r"C:\Users\You\Desktop\Σχολή\MR_EGB\apr3\alpha_list.csv")

# %%
df
# Out:
#               M          R        p_c    a
# 0      0.320104  12.551898   0.100000 -0.4
# 1      0.325966  12.504011   0.102552 -0.4
# 2      0.331934  12.458103   0.105169 -0.4
# 3      0.337987  12.414462   0.107853 -0.4
# 4      0.344131  12.372970   0.110606 -0.4
# ...         ...        ...        ...  ...
# 10195  2.897169  10.847377  17.397070  9.2
# 10196  2.896483  10.816631  17.863466  9.2
# 10197  2.895602  10.785678  18.342366  9.2
# 10198  2.894531  10.754526  18.834104  9.2
# 10199  2.893273  10.723177  19.339026  9.2
#
# [10200 rows x 4 columns]

# %%
# df.to_csv(r"C:\Users\You\Desktop\Σχολή\MR_EGB\apr3\MRpa_data.csv")

# %%
# All linear
n_lines = int(len(df)/200)

a = alpha_list
clrs = a.copy()
clrs.sort()

norm = mpl.colors.Normalize(vmin=min(a), vmax=max(a))
cmap = mpl.cm.ScalarMappable(norm=norm, cmap=mpl.cm.coolwarm)
cmap.set_array([])

fig, ax = plt.subplots(1,3, figsize = (18,6))
for i in range(len(alpha_list)):
    temp = df[df['a'] == alpha_list[i]]
    
    r  = temp.R.values
    m  = temp.M.values
    pc = temp.p_c.values
    
    ax[0].plot(r, m, c=cmap.to_rgba(alpha_list[i]))
    # ax[0].tick_params(axis='both', which='major', labelsize=10)
    
    ax[1].plot(pc, m, c=cmap.to_rgba(alpha_list[i]))
    
    ax[2].plot(pc, r, c=cmap.to_rgba(alpha_list[i]))


cbar = fig.colorbar(cmap, ticks=clrs[::3])
cbar.set_label('$a$ [$km^2$]', fontsize = 20, rotation=90)

name = "$R$ [$"+units["R"]+"$]"
ax[0].set_xlabel(name, fontsize = 20)
name = "$M$ [$"+units["M"]+"$]"
ax[0].set_ylabel(name, fontsize = 20)

name = "$p_c$ [$"+units["p_c"]+"$]"
ax[1].set_xlabel(name, fontsize = 20)
name = "$M$ [$"+units["M"]+"$]"
ax[1].set_ylabel(name, fontsize = 20)

name = "$p_c$ [$"+units["p_c"]+"$]"
ax[2].set_xlabel(name, fontsize = 20)
name = "$R$ [$"+units["R"]+"$]"
ax[2].set_ylabel(name, fontsize = 20)

plt.show()




# All log
n_lines = int(len(df)/200)

a = alpha_list
clrs = a.copy()
clrs.sort()

norm = mpl.colors.Normalize(vmin=min(a), vmax=max(a))
cmap = mpl.cm.ScalarMappable(norm=norm, cmap=mpl.cm.coolwarm)
cmap.set_array([])

fig, ax = plt.subplots(1,3, figsize = (18,6))
for i in range(len(alpha_list)):
    temp = df[df['a'] == alpha_list[i]]
    
    r  = temp.R.values
    m  = temp.M.values
    pc = temp.p_c.values
    
    ax[0].loglog(r, m, c=cmap.to_rgba(alpha_list[i]))
    # ax[0].tick_params(axis='both', which='major', labelsize=10)
    
    ax[1].loglog(pc, m, c=cmap.to_rgba(alpha_list[i]))
    
    ax[2].loglog(pc, r, c=cmap.to_rgba(alpha_list[i]))


cbar = fig.colorbar(cmap, ticks=clrs[::3])
cbar.set_label('$a$ [$km^2$]', fontsize = 20, rotation=90)

name = "$R$ [$"+units["R"]+"$]"
ax[0].set_xlabel(name, fontsize = 20)
name = "$M$ [$"+units["M"]+"$]"
ax[0].set_ylabel(name, fontsize = 20)

name = "$p_c$ [$"+units["p_c"]+"$]"
ax[1].set_xlabel(name, fontsize = 20)
name = "$M$ [$"+units["M"]+"$]"
ax[1].set_ylabel(name, fontsize = 20)

name = "$p_c$ [$"+units["p_c"]+"$]"
ax[2].set_xlabel(name, fontsize = 20)
name = "$R$ [$"+units["R"]+"$]"
ax[2].set_ylabel(name, fontsize = 20)

plt.show()




# p_c log
n_lines = int(len(df)/200)

a = alpha_list
clrs = a.copy()
clrs.sort()

norm = mpl.colors.Normalize(vmin=min(a), vmax=max(a))
cmap = mpl.cm.ScalarMappable(norm=norm, cmap=mpl.cm.coolwarm)
cmap.set_array([])

fig, ax = plt.subplots(1,3, figsize = (18,6))
for i in range(len(alpha_list)):
    temp = df[df['a'] == alpha_list[i]]
    
    r  = temp.R.values
    m  = temp.M.values
    pc = temp.p_c.values
    
    ax[0].plot(r, m, c=cmap.to_rgba(alpha_list[i]))
    # ax[0].tick_params(axis='both', which='major', labelsize=10)
    
    ax[1].semilogx(pc, m, c=cmap.to_rgba(alpha_list[i]))
    
    ax[2].semilogx(pc, r, c=cmap.to_rgba(alpha_list[i]))


cbar = fig.colorbar(cmap, ticks=clrs[::3])
cbar.set_label('$a$ [$km^2$]', fontsize = 20, rotation=90)

name = "$R$ [$"+units["R"]+"$]"
ax[0].set_xlabel(name, fontsize = 20)
name = "$M$ [$"+units["M"]+"$]"
ax[0].set_ylabel(name, fontsize = 20)

name = "$p_c$ [$"+units["p_c"]+"$]"
ax[1].set_xlabel(name, fontsize = 20)
name = "$M$ [$"+units["M"]+"$]"
ax[1].set_ylabel(name, fontsize = 20)

name = "$p_c$ [$"+units["p_c"]+"$]"
ax[2].set_xlabel(name, fontsize = 20)
name = "$R$ [$"+units["R"]+"$]"
ax[2].set_ylabel(name, fontsize = 20)

plt.show()



# p_c log R log
n_lines = int(len(df)/200)

a = alpha_list
clrs = a.copy()
clrs.sort()

norm = mpl.colors.Normalize(vmin=min(a), vmax=max(a))
cmap = mpl.cm.ScalarMappable(norm=norm, cmap=mpl.cm.coolwarm)
cmap.set_array([])

fig, ax = plt.subplots(1,3, figsize = (18,6))
for i in range(len(alpha_list)):
    temp = df[df['a'] == alpha_list[i]]
    
    r  = temp.R.values
    m  = temp.M.values
    pc = temp.p_c.values
    
    ax[0].semilogx(r, m, c=cmap.to_rgba(alpha_list[i]))
    # ax[0].tick_params(axis='both', which='major', labelsize=10)
    
    ax[1].semilogx(pc, m, c=cmap.to_rgba(alpha_list[i]))
    
    ax[2].loglog(pc, r, c=cmap.to_rgba(alpha_list[i]))


cbar = fig.colorbar(cmap, ticks=clrs[::3])
cbar.set_label('$a$ [$km^2$]', fontsize = 20, rotation=90)

name = "$R$ [$"+units["R"]+"$]"
ax[0].set_xlabel(name, fontsize = 20)
name = "$M$ [$"+units["M"]+"$]"
ax[0].set_ylabel(name, fontsize = 20)

name = "$p_c$ [$"+units["p_c"]+"$]"
ax[1].set_xlabel(name, fontsize = 20)
name = "$M$ [$"+units["M"]+"$]"
ax[1].set_ylabel(name, fontsize = 20)

name = "$p_c$ [$"+units["p_c"]+"$]"
ax[2].set_xlabel(name, fontsize = 20)
name = "$R$ [$"+units["R"]+"$]"
ax[2].set_ylabel(name, fontsize = 20)

plt.show()




# p_c log M log
n_lines = int(len(df)/200)

a = alpha_list
clrs = a.copy()
clrs.sort()

norm = mpl.colors.Normalize(vmin=min(a), vmax=max(a))
cmap = mpl.cm.ScalarMappable(norm=norm, cmap=mpl.cm.coolwarm)
cmap.set_array([])

fig, ax = plt.subplots(1,3, figsize = (18,6))
for i in range(len(alpha_list)):
    temp = df[df['a'] == alpha_list[i]]
    
    r  = temp.R.values
    m  = temp.M.values
    pc = temp.p_c.values
    
    ax[0].semilogy(r, m, c=cmap.to_rgba(alpha_list[i]))
    # ax[0].tick_params(axis='both', which='major', labelsize=10)
    
    ax[1].loglog(pc, m, c=cmap.to_rgba(alpha_list[i]))
    
    ax[2].semilogx(pc, r, c=cmap.to_rgba(alpha_list[i]))


cbar = fig.colorbar(cmap, ticks=clrs[::3])
cbar.set_label('$a$ [$km^2$]', fontsize = 20, rotation=90)

name = "$R$ [$"+units["R"]+"$]"
ax[0].set_xlabel(name, fontsize = 20)
name = "$M$ [$"+units["M"]+"$]"
ax[0].set_ylabel(name, fontsize = 20)

name = "$p_c$ [$"+units["p_c"]+"$]"
ax[1].set_xlabel(name, fontsize = 20)
name = "$M$ [$"+units["M"]+"$]"
ax[1].set_ylabel(name, fontsize = 20)

name = "$p_c$ [$"+units["p_c"]+"$]"
ax[2].set_xlabel(name, fontsize = 20)
name = "$R$ [$"+units["R"]+"$]"
ax[2].set_ylabel(name, fontsize = 20)

plt.show()

# %% [markdown]
# **Best choice: ALL LOG**

# %%
plt.plot(temp.M)
x = np.linspace(0,200,100)
plt.plot(x,np.ones(len(x))*max(temp.M.values))
plt.plot(np.ones(len(x))*192, np.linspace(0.2,3,100))

# %%
for i, j in enumerate(temp.M.values):
    if j == max(temp.M.values):
        print(i)
# Out:
# 192
